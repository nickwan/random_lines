# %%
import cairo
import math
import numpy as np
from IPython.display import SVG, display, Image
import itertools
import random

def show_svg(file):
    display(SVG(filename=file))

def show_png(file):
    display(Image(filename=file))

def point_on_circ(cx,cy,r,a):
    x = cx + r * math.cos((-a*(math.pi/180)))
    y = cy + r * math.sin((-a*(math.pi/180)))
    return (x,y)

def deg2rad(a):
    return a*(math.pi/180)

def draw_square(context, x,y,l,a, helper=False):
    x1,y1  = set_square(x,y,l)
    
    if helper:
        context.save()
        context.move_to(x,y)
        context.set_source_rgba(1,0,0)
        context.set_line_width(2)
        context.arc(x,y, round(l/2), 0, 2*math.pi)
        context.stroke()

    context.save()
    context.set_source_rgb(0,0,0)
    context.set_line_width(1)
    context.translate(x,y)
    context.rotate(deg2rad(a))
    context.translate(-x,-y)
    context.rectangle(x1,y1,l,l)
    context.stroke()
    context.restore()

def set_square(x,y,l):
    _x = x-(round(l/2))
    _y = y-(round(l/2))
    return (_x,_y)

# %%
WIDTH = 400
HEIGHT = 400 
xc = WIDTH/2
yc = HEIGHT/2

surface = cairo.ImageSurface(cairo.FORMAT_ARGB32, WIDTH, HEIGHT)
context = cairo.Context(surface)
context.set_source_rgb(1, 1, 1)
context.paint()

draw_square(context,xc,yc,50,0)
surface.write_to_png("img/lines/example.png")  # Output to PNG
show_png('img/lines/example.png')

# %%
WIDTH = 400
HEIGHT = 400 
xc = WIDTH/2
yc = HEIGHT/2

surface = cairo.ImageSurface(cairo.FORMAT_ARGB32, WIDTH, HEIGHT)
context = cairo.Context(surface)
context.set_source_rgb(1, 1, 1)
context.paint()

for _ in range(173):
    line_length = random.randint(1,290)
    angle = random.randint(0,360)
    context.set_source_rgb(0, 0, 0)
    
    if not random.randint(0,20):
        context.set_source_rgb(1, 0, 0)
    
    context.set_line_width(random.randint(1,15))
    context.save()

    context.translate(xc,yc)
    context.rotate(angle*(math.pi/180)) # needs radians 
    context.translate(-xc,-yc)

    context.move_to(xc,yc-(line_length/2))
    context.line_to(xc,(yc-(line_length/2))+line_length)
    context.stroke()

surface.write_to_png("img/lines/example3.png")  # Output to PNG
show_png('img/lines/example3.png')

# %%
WIDTH = 400
HEIGHT = 400 
xc = WIDTH/2
yc = HEIGHT/2

surface = cairo.ImageSurface(cairo.FORMAT_ARGB32, WIDTH, HEIGHT)
context = cairo.Context(surface)
context.set_source_rgb(1, 1, 1)
context.paint()

for _ in range(173):
    line_length = random.randint(1,290)
    angle = random.randint(0,360)
    hue = angle/(angle+random.randint(0,360)) 
    context.set_source_rgb(angle/(angle+random.randint(0,360)), angle/(angle+random.randint(0,360)), angle/(angle+random.randint(0,360)))
    
    if not random.randint(0,20):
            context.set_source_rgb(0, 0, 0)
    
    context.set_line_width(random.randint(1,15))
    context.save()

    context.translate(xc,yc)
    context.rotate(angle*(math.pi/180)) # needs radians 
    context.translate(-xc,-yc)

    context.move_to(xc,yc-(line_length/2))
    context.line_to(xc,(yc-(line_length/2))+line_length)
    context.stroke()

surface.write_to_png("img/lines/example4.png")  # Output to PNG
show_png('img/lines/example4.png')

# %%
WIDTH = 400
HEIGHT = 400 
xc = WIDTH/2
yc = HEIGHT/2

surface = cairo.ImageSurface(cairo.FORMAT_ARGB32, WIDTH, HEIGHT)
context = cairo.Context(surface)
context.set_source_rgb(1, 1, 1)
context.paint()

for _ in range(173):
    loc_x = random.randint(0,400)
    loc_y = random.randint(0,400)
    
    line_length = random.randint(1,290)
    angle = random.randint(0,360)
    hue = angle/(angle+random.randint(0,360)) 
    context.set_source_rgb(angle/(angle+random.randint(0,360)), angle/(angle+random.randint(0,360)), angle/(angle+random.randint(0,360)))
    
    if not random.randint(0,20):
            context.set_source_rgb(0, 0, 0)
    
    context.set_line_width(random.randint(1,15))
    context.save()

    context.translate(xc,yc)
    context.rotate(angle*(math.pi/180)) # needs radians 
    context.translate(-xc,-yc)

    context.move_to(loc_x,loc_y-(line_length/2))
    context.line_to(loc_x,(loc_y-(line_length/2))+line_length)
    context.stroke()

surface.write_to_png("img/lines/example5.png")  # Output to PNG
show_png('img/lines/example5.png')

# %%
WIDTH = 400
HEIGHT = 400 
xc = WIDTH/2
yc = HEIGHT/2

surface = cairo.ImageSurface(cairo.FORMAT_ARGB32, WIDTH, HEIGHT)
context = cairo.Context(surface)
context.set_source_rgb(1, 1, 1)
context.paint()

for _ in range(50):
    loc_x = random.randint(0,400)
    loc_y = random.randint(0,400)
    
    line_length = random.randint(1,566)
    angle = random.randint(0,360)
    hue = angle/(angle+random.randint(0,360)) 
    context.set_source_rgb(angle/(angle+random.randint(0,360)), angle/(angle+random.randint(0,360)), angle/(angle+random.randint(0,360)))
    
    if not random.randint(0,20):
            context.set_source_rgb(0, 0, 0)
    
    context.set_line_width(random.randint(1,5))
    context.save()

    context.translate(xc,yc)
    context.rotate(angle*(math.pi/180)) # needs radians 
    context.translate(-xc,-yc)

    context.move_to(loc_x,loc_y-(line_length/2))
    context.line_to(loc_x,(loc_y-(line_length/2))+line_length)
    context.stroke()

surface.write_to_png("img/lines/example6.png")  # Output to PNG
show_png('img/lines/example6.png')

# %%
# alpha = alpha
alpha
# Out:
# 0.86

# %%
loc_x, loc_y
# Out:
# (64, 234)

# %%
filename = "img/lines/example7.png"

WIDTH = 400
HEIGHT = 400 
xc = WIDTH/2
yc = HEIGHT/2

surface = cairo.ImageSurface(cairo.FORMAT_ARGB32, WIDTH, HEIGHT)
context = cairo.Context(surface)
context.set_source_rgb(1, 1, 1)
context.paint()

for _ in range(100):
    max_radius = random.randint(25,50)
    radius = random.randint(10,max_radius)

    loc_x = random.randint(0+(2*max_radius),400-(2*max_radius))
    loc_y = random.randint(0+(2*max_radius),400-(2*max_radius))

    context.set_source_rgb(0,0,0)

    context.arc(loc_x, loc_y, radius+random.randint(1,20), 0, 2*math.pi)
    context.fill()

    context.set_source_rgb(1,1,1)
    context.arc(loc_x, loc_y, radius, 0, 2*math.pi)
    context.fill()

    alpha = random.randrange(40,100)/100

    context.set_source_rgba(angle/(angle+random.randint(0,360)), 
                            angle/(angle+random.randint(0,360)), 
                            angle/(angle+random.randint(0,360)), 
                            alpha)
    context.arc(loc_x, loc_y, radius, 0, 2*math.pi)
    context.fill()

surface.write_to_png(filename)  # Output to PNG
show_png(filename)

# %%
filename = "img/lines/example18.png"

WIDTH = 400
HEIGHT = 400 
xc = WIDTH/2
yc = HEIGHT/2

surface = cairo.ImageSurface(cairo.FORMAT_ARGB32, WIDTH, HEIGHT)
context = cairo.Context(surface)
context.set_source_rgb(1, 1, 1)
context.paint()

circles_appear = [random.randint(0,19), 
                  random.randint(0,19), 
                  random.randint(0,19)]

for ix in range(20):
    if ix in circles_appear:
        max_radius = random.randint(15,60)
        radius = random.randint(3,max_radius)

        loc_x = random.randint(0+(2*max_radius),400-(2*max_radius))
        loc_y = random.randint(0+(2*max_radius),400-(2*max_radius))

        alpha = random.randrange(40,100)/100
        alpha_black = alpha + random.randrange(1,10)/100
        context.set_source_rgba(0,0,0,alpha_black)

        context.arc(loc_x, loc_y, radius+random.randint(1,20), 0, 2*math.pi)
        context.fill()

        context.set_source_rgb(1,1,1)
        context.arc(loc_x, loc_y, radius, 0, 2*math.pi)
        context.fill()

        context.set_source_rgba(angle/(angle+random.randint(0,360)), 
                                angle/(angle+random.randint(0,360)), 
                                angle/(angle+random.randint(0,360)), 
                                alpha)
        context.arc(loc_x, loc_y, radius, 0, 2*math.pi)
        context.fill()
    
    loc_x = random.randint(0,400)
    loc_y = random.randint(0,400)
    
    line_length = random.randint(1,566)
    angle = random.randint(0,360)
    hue = angle/(angle+random.randint(0,360)) 
    context.set_source_rgb(angle/(angle+random.randint(0,360)), angle/(angle+random.randint(0,360)), angle/(angle+random.randint(0,360)))
    
    if not random.randint(0,20):
            context.set_source_rgb(0, 0, 0)
    
    context.set_line_width(random.randint(1,5))
    context.save()

    context.translate(xc,yc)
    context.rotate(angle*(math.pi/180)) # needs radians 
    context.translate(-xc,-yc)

    context.move_to(loc_x,loc_y-(line_length/2))
    context.line_to(loc_x,(loc_y-(line_length/2))+line_length)
    context.stroke()

surface.write_to_png(filename)  # Output to PNG
show_png(filename)

# %%
def draw_line(context, loc_x,loc_y, angle, max_width):
    """
    draw rand line like in that one stream nw did!
    
    inputs:
        context: pycairo context
        loc_x: x location (pixels)
        loc_y: y location (pixels)  
        angle: angle (degrees)
        max_width: max line width possible
        
    output:
        a line on the canvas  
    
    Note: The line can start or end off the canvas  
        
    """
    
    line_length = random.randint(1,566)
    angle = random.randint(0,360)
    hue = angle/(angle+random.randint(0,360)) 
    context.set_source_rgb(angle/(angle+random.randint(0,360)), angle/(angle+random.randint(0,360)), angle/(angle+random.randint(0,360)))
    
    if not random.randint(0,20):
        context.set_source_rgb(0, 0, 0)
    
    context.set_line_width(random.randint(1,max_width))
    context.save()

    context.translate(xc,yc)
    context.rotate(angle*(math.pi/180)) # needs radians 
    context.translate(-xc,-yc)

    context.move_to(loc_x,loc_y-(line_length/2))
    context.line_to(loc_x,(loc_y-(line_length/2))+line_length)
    context.stroke()
    
def draw_circle(context,loc_x,loc_y, min_radius, max_lo_radius, max_hi_radius, canvas_width, canvas_height, alpha):
    """
    draw rand circle like in that one stream nw did!
    
    inputs:
        context: pycairo context
        loc_x: x location (pixels)
        loc_y: y location (pixels)  
        min_radius: smallest circle radius possible  
        max_lo_radius: smallest "max" possible 
        max_hi_radius: largest "max" possible 
        canvas_width: canvas width max 
        canvas_height: canvas height max 
        
    output:
        a circle within the canvas bounds 
    
    Note: Circle does not expand beyond the given bounds
        
    """
    
    alpha_black = alpha + random.randrange(1,10)/100
    context.set_source_rgba(0,0,0,alpha_black)

    context.arc(loc_x, loc_y, radius+random.randint(1,20), 0, 2*math.pi)
    context.fill()

    context.set_source_rgb(1,1,1)
    context.arc(loc_x, loc_y, radius, 0, 2*math.pi)
    context.fill()

    context.set_source_rgba(angle/(angle+random.randint(0,360)), 
                            angle/(angle+random.randint(0,360)), 
                            angle/(angle+random.randint(0,360)), 
                            alpha)
    context.arc(loc_x, loc_y, radius, 0, 2*math.pi)
    context.fill()

# %%
filename = "img/lines/example19.png"

WIDTH = 400
HEIGHT = 400 
xc = WIDTH/2
yc = HEIGHT/2

surface = cairo.ImageSurface(cairo.FORMAT_ARGB32, WIDTH, HEIGHT)
context = cairo.Context(surface)
context.set_source_rgb(1, 1, 1)
context.paint()

circles_appear = [random.randint(0,19), 
                  random.randint(0,19), 
                  random.randint(0,19)]

for ix in range(20):
    if ix in circles_appear:
        loc_x = random.randint(0+(2*max_radius),400-(2*max_radius))
        loc_y = random.randint(0+(2*max_radius),400-(2*max_radius))
        
        draw_circle(context,loc_x,loc_y, min_radius=3, max_lo_radius=15, 
                    max_hi_radius=60, canvas_width=WIDTH, 
                    canvas_height=HEIGHT, alpha=random.randrange(40,100)/100)
   
    loc_x = random.randint(0,400)
    loc_y = random.randint(0,400)
    draw_line(context, loc_x, loc_y, random.randint(0,360), 5)

surface.write_to_png(filename)  # Output to PNG
show_png(filename)

# %% [markdown]
# # image names
# ~~fuck_i_spilled_my_crayons~~
# ~~WEIRD_RANDOM_LINES_1~~
#
# ~~is_this_what_baseball_looks_like~~
# ~~executive_authority~~
# ~~this_is_your_brain_on_memes~~
# ~~best_served_with_a_glass_of_lsd~~
